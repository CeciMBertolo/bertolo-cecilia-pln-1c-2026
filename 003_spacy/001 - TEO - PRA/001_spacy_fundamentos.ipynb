# %% [markdown]
# # spaCy: fundamentos para analizar texto en español
#
# **Duración estimada:** 35 minutos
#
# ## Propósito
# En este notebook vas a practicar las operaciones básicas de `spaCy` sobre ejemplos breves. La idea es que puedas mirar una salida, interpretarla y decidir para qué sirve.
#
# ## Cómo trabajar este material
# - Ejecutá cada bloque y frena a leer la salida antes de avanzar.
# - Si usas un asistente de IA, pedile hipótesis o explicaciones alternativas, pero contrastalas siempre con lo que devuelve el código.
#
# ## Resultados de aprendizaje
# Al finalizar, vas a poder:
# - reconocer tokens, lemas y etiquetas gramaticales;
# - leer una visualización de dependencias y de entidades;
# - identificar grupos nominales;
# - comprender, a nivel introductorio, como se agrega una personalización simple al pipeline.

# %%
# !pip install spacy -q
# !python -m spacy download es_core_news_sm -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 55.4 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from collections import Counter
from spacy import displacy

nlp = spacy.load("es_core_news_sm")

# %% [markdown]
# ## Caso 1: tokenización, lema y categoría gramatical
#
# En este primer caso vamos a observar cómo `spaCy` divide una oración y que información le asigna a cada token.
#
# **Qué deberías mirar:**
# - dónde corta los tokens;
# - qué lema propone para cada palabra;
# - qué etiquetas POS aparecen con más frecuencia.

# %%
doc = nlp("Yo, Matías Barreto, estoy volando hacia Buenos Aires.")
print([token.text for token in doc])
# Out:
# ['Yo', ',', 'Matías', 'Barreto', ',', 'estoy', 'volando', 'hacia', 'Buenos', 'Aires', '.']

# %%
print("La cantidad de tokens es:", len(doc))
# Out:
# La cantidad de tokens es: 11

# %%
print("Tokens del documento")
print("_" * 20)
for token in doc:
    print(token)
# Out:
# Tokens del documento
# ____________________
# Yo
# ,
# Matías
# Barreto
# ,
# estoy
# volando
# hacia
# Buenos
# Aires
# .

# %%
for token in doc:
    print(token.text, token.lemma_)
# Out:
# Yo yo
# , ,
# Matías Matías
# Barreto Barreto
# , ,
# estoy estar
# volando volar
# hacia hacia
# Buenos Buenos
# Aires Aires
# . .

# %%
for token in doc:
    print(token.text, token.pos_, spacy.explain(token.pos_))
# Out:
# Yo PRON pronoun
# , PUNCT punctuation
# Matías PROPN proper noun
# Barreto PROPN proper noun
# , PUNCT punctuation
# estoy AUX auxiliary
# volando VERB verb
# hacia ADP adposition
# Buenos PROPN proper noun
# Aires PROPN proper noun
# . PUNCT punctuation

# %%
frecuencias = Counter(token.text for token in doc)
print(frecuencias)
# Out:
# Counter({',': 2, 'Yo': 1, 'Matías': 1, 'Barreto': 1, 'estoy': 1, 'volando': 1, 'hacia': 1, 'Buenos': 1, 'Aires': 1, '.': 1})

# %% [markdown]
# **Pausa de lectura**
#
# En este caso conviene diferenciar tres niveles:
# - el texto original del token (`token.text`);
# - la forma base (`token.lemma_`);
# - la función gramatical (`token.pos_`).
#
# Esa distinción va a ser clave cuando trabajes con noticias o corpus más grandes.

# %% [markdown]
# ## Caso 2: lemas y dependencias sintácticas
#
# Ahora vamos a mirar relaciones entre palabras. Las dependencias sirven para ver cómo se organiza una oración y que vínculos gramaticales aparecen.

# %%
doc = nlp("En abril de 2026 estaremos realizando una introducción a spaCy para trabajar conceptos básicos de PLN.")
for token in doc:
    print(token.text, token.lemma_)
# Out:
# En en
# abril abril
# de de
# 2026 2026
# estaremos estarer
# realizando realizar
# una uno
# introducción introducción
# a a
# spaCy spaCy
# para para
# trabajar trabajar
# conceptos concepto
# básicos básico
# de de
# PLN PLN
# . .

# %%
from spacy.lang.es.examples import sentences

doc = nlp(sentences[11])
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# ¿Cuándo nació José de San Martín?
# ¿ PUNCT punct
# Cuándo PRON obj
# nació VERB ROOT
# José PROPN nsubj
# de ADP case
# San PROPN flat
# Martín PROPN flat
# ? PUNCT punct

# %%
conteo_pos = Counter(token.pos_ for token in doc)
print(conteo_pos)
# Out:
# Counter({'PROPN': 3, 'PUNCT': 2, 'PRON': 1, 'VERB': 1, 'ADP': 1})

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="963f82868aec496b8344c731b238279d-0" class="displacy" width="890" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">¿</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Cuándo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">nació</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">José</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">San</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Martín?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-963f82868aec496b8344c731b238279d-0-0" stroke-width="2px" d="M70,122.0 C70,2.0 290.0,2.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-963f82868aec496b8344c731b238279d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-963f82868aec496b8344c731b238279d-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-963f82868aec496b8344c731b238279d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-963f82868aec496b8344c731b238279d-0-2" stroke-width="2px" d="M310,122.0 C310,62.0 405.0,62.0 405.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-963f82868aec496b8344c731b238279d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M405.0,124.0 L413.0,112.0 397.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-963f82868aec496b8344c731b238279d-0-3" stroke-width="2px" d="M550,122.0 C550,62.0 645.0,62.0 645.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-963f82868aec496b8344c731b238279d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,124.0 L542,112.0 558,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-963f82868aec496b8344c731b238279d-0-4" stroke-width="2px" d="M430,122.0 C430,2.0 650.0,2.0 650.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-963f82868aec496b8344c731b238279d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,124.0 L658.0,112.0 642.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-963f82868aec496b8344c731b238279d-0-5" stroke-width="2px" d="M670,122.0 C670,62.0 765.0,62.0 765.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-963f82868aec496b8344c731b238279d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M765.0,124.0 L773.0,112.0 757.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# **Preguntas para guiar tu lectura**
#
# - Cuál parece ser el verbo principal de la oración?
# - Qué palabras dependen de ese verbo?
# - Qué información te aporta la visualización que no veías tan rápido en la lista de tokens?

# %% [markdown]
# ## Caso 3: entidades nombradas
#
# En este caso vamos a mirar cómo `spaCy` detecta nombres propios, lugares y otras entidades relevantes.

# %%
text = "Queremos viajar desde Buenos Aires a Mar del Plata y, unos días después, a La Plata."
doc = nlp(text)
displacy.render(doc, style='ent', jupyter=True, options={'distance': 200})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Queremos viajar desde
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buenos Aires
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mar del Plata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y, unos días después, a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La Plata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>

# %%
text = "Su nombre es Benjamín; nació en Argentina."
doc = nlp(text)
displacy.render(doc, style='ent', jupyter=True, options={'distance': 200})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Su nombre es
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benjamín
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ; nació en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Argentina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="8d2774f90f7f4f2aa2ee92d9c9e1fcea-0" class="displacy" width="890" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Su</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">nombre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">es</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Benjamín;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">nació</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Argentina.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-0" stroke-width="2px" d="M70,122.0 C70,62.0 165.0,62.0 165.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-1" stroke-width="2px" d="M190,122.0 C190,2.0 410.0,2.0 410.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-2" stroke-width="2px" d="M310,122.0 C310,62.0 405.0,62.0 405.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,124.0 L302,112.0 318,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-3" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,124.0 L422,112.0 438,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-4" stroke-width="2px" d="M670,122.0 C670,62.0 765.0,62.0 765.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,124.0 L662,112.0 678,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-5" stroke-width="2px" d="M550,122.0 C550,2.0 770.0,2.0 770.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8d2774f90f7f4f2aa2ee92d9c9e1fcea-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,124.0 L778.0,112.0 762.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# **Importante**
#
# Los modelos no aciertan siempre. Si una entidad te parece discutible, no la des por válida automáticamente: usala como punto de análisis.

# %% [markdown]
# ## Caso 4: grupos nominales
#
# Los grupos nominales (`noun_chunks`) te ayudan a detectar segmentos como `"mis padres"` o `"Buenos Aires"` cuando funcionan como unidades dentro de la oración.

# %%
for token in nlp("Mis padres y amigos viven en Buenos Aires."):
    print(token.text)
# Out:
# Mis
# padres
# y
# amigos
# viven
# en
# Buenos
# Aires
# .

# %%
for chunk in nlp("Mis padres y amigos viven en Buenos Aires.").noun_chunks:
    print(chunk.text)
# Out:
# Mis padres
# amigos
# Buenos Aires

# %% [markdown]
# En este punto conviene comparar la lista completa de tokens con la lista de grupos nominales: no muestran lo mismo ni sirven para la misma tarea.

# %% [markdown]
# ## Caso 5: extensión opcional - personalizar la lematización
#
# Este caso es más avanzado. No hace falta dominarlo ahora, pero sirve para entender que el pipeline también se puede adaptar a necesidades puntuales.

# %%
doc = nlp("Estoy volando hacia Baires")
print([token.text for token in doc])
# Out:
# ['Estoy', 'volando', 'hacia', 'Baires']

# %%
from spacy.language import Language

# %%
@Language.component("custom_lemmatizer")
def custom_lemmatizer(doc):
    for token in doc:
        if token.text == "Baires":
            token.lemma_ = "Buenos Aires"
    return doc

if "custom_lemmatizer" in nlp.pipe_names:
    nlp.remove_pipe("custom_lemmatizer")

nlp.add_pipe("custom_lemmatizer", after="lemmatizer")

doc = nlp("Estoy volando a Baires")
print([token.text for token in doc])
print([token.lemma_ for token in doc])
# Out:
# ['Estoy', 'volando', 'a', 'Baires']
# ['estar', 'volar', 'a', 'Buenos Aires']

# %% [markdown]
# ## Cierre y continuidad
#
# Antes de pasar al siguiente notebook, comprobá si podés responder estas preguntas sin mirar las celdas anteriores:
# - Qué diferencia hay entre token, lema y POS?
# - Para qué sirve mirar dependencias?
# - Por qué una entidad detectada por el modelo no siempre debe aceptarse sin revisión?
#
# **Actividad breve con IA:** pedile a un asistente que te proponga una oración y que anticipe cómo la tokenizaría `spaCy`. Después corré esa oración en el notebook y compará ambas lecturas.
